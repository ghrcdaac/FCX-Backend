# %% [markdown]
# HIWRAP 3d tile viz

# %%
import os
import zarr
import numpy as np
import xarray as xr
import shutil
import boto3
from pathlib import Path

# %% [markdown]
# UTILS

# %%
import numpy as np
import pandas as pd
import xarray as xr
import glob, os, io
import gzip
import boto3, s3fs
from boto3 import client as boto_client
from datetime import date, time, datetime, timedelta

def down_vector(roll, pitch, head):
    x = np.sin(roll) * np.cos(head) + np.cos(roll) * np.sin(pitch) * np.sin(head)
    y = -np.sin(roll) * np.sin(head) + np.cos(roll) * np.sin(pitch) * np.cos(head)
    z = -np.cos(roll) * np.cos(pitch)
    return (x, y, z)


def add24hr(hr):
    """Correction of time in CRS for going over the next day in UTC"""
    b = np.where(hr < hr[0])
    hr[b] = hr[b] + 24
    return hr


def CRSaccess(fname, s3bucket=False, Verb=False):
    """
    Access the CRS file
    Return CRS filename with path (absolute path) for "local" access
    Return CRS data as object for "cloud access"
    Either way, the return value can be open by Xarray as netcdf file object
    """

    print("\%% Accessing data from Cloud. This may take a little time...\n")
    s3 = boto_client('s3')
    fileobj = s3.get_object(Bucket=s3bucket, Key=fname)
    fileCRS = fileobj['Body'].read()
    

def upload_to_s3(file_name, bucket, s3_name=None):
    """Upload a file to an S3 bucket
     file_name: File to upload
     bucket: S3 bucket to upload to
     object_name: S3 object name. If not specified then file_name is used
    """
    if s3_name is None: s3_name = file_name

    s3 = boto3.client('s3')
    try:
        s3.upload_file(file_name, bucket, s3_name)
    except ClientError as e:
       print(e)
    except NoCredentialsError:
        print("%%Credentials not available")

# %%
import os
import json
import numpy as np
from datetime import datetime
from threading import Thread, Lock

to_rad = np.pi / 180.0
to_deg = 180.0 / np.pi

steps = [32, 16, 8, 4, 2, 1]

class PointCloud:
    def __init__(self, key, lon, lat, alt, value, time, epoch):
        self.key = key
        self.lon = lon
        self.lat = lat
        self.alt = alt
        self.time = time
        self.value = value
        self.epoch = epoch
        self.tasks = []
        self.threads = []
        for i in range(10):
            self.threads.append(Thread(target=self.worker_function))
        self.tileset_lock = Lock()
        self.tileset_json = {
        	"asset": {
        		"version": "1.0",
        		"type": "Airborne Radar"
        	},
        	"root": {
        		"geometricError": 1000000,
        		"refine" : "REPLACE",
        		"boundingVolume": {
                    "region": [
                        float(np.min(lon)) * to_rad,
                        float(np.min(lat)) * to_rad,
                        float(np.max(lon)) * to_rad,
                        float(np.max(lat)) * to_rad,
                        float(np.min(alt)) * to_rad,
                        float(np.max(alt)) * to_rad
                    ]
                },
                "children": []
        	},
            "properties": {
                "epoch": "{}Z".format(datetime.utcfromtimestamp(epoch).isoformat()),
                "refined": []
            }
        }


    def worker_function(self):
        while len(self.tasks) > 0:
                tile, start, end = self.tasks.pop()
                print(tile, start, end)
                self.generate(tile, start, end)


    def start(self):
        for t in self.threads:
            t.start()


    def join(self):
        for t in self.threads:
            t.join()
        with open('{}/tileset.json'.format(self.key), mode='w+') as outfile:
            json.dump(self.tileset_json, outfile)


    def schedule_task(self, tile, start, end):
        self.tasks.append((tile, start, end))


    def generate(self, tile, start, end):
        print(tile, start, end)
        parent_tile = self.tileset_json["root"]
        cartesian, offset, scale, cartographic, region = self.cartographic_to_cartesian(start, end)

        value = self.value[start:end]
        time = self.time[start:end]

        epoch = int(np.min(time) + self.epoch - 300)
        epoch = "{}Z".format(datetime.utcfromtimestamp(epoch).isoformat())
        end = int(np.max(time) + self.epoch + 300)
        end = "{}Z".format(datetime.utcfromtimestamp(end).isoformat())

        header_length = 28
        magic = np.string_("pnts")
        version = 1

        for step in steps:
            self.tileset_lock.acquire()
            try:
                filename = "{}_{}.pnts".format(tile, step)
                child_tile = {
                    "availability": "{}/{}".format(epoch, end),
                    "geometricError": step * 500,
                    "boundingVolume": {
                        "region": region
                    },
                    "content": {
                        "uri": filename
                    },
                    "refine": "REPLACE"
                }
                if step == 1:
                    self.tileset_json["properties"]["refined"].append(filename)
                else:
                    child_tile["children"] = []
                parent_tile["children"].append(child_tile)
                parent_tile = child_tile
            finally:
                self.tileset_lock.release()

            tile_length = 0
            feature_table_binary_byte_length = 0
            batch_table_binary_byte_length = 0
            length = value[::step].size

            feature_table_json = {
                "POINTS_LENGTH": length,
                "BATCH_LENGTH": length,
                "BATCH_ID": {
                    "byteOffset": 0,
                    "componentType": "UNSIGNED_INT"
                },
                "POSITION_QUANTIZED": {
                    "byteOffset": length * 4
                },
                "QUANTIZED_VOLUME_OFFSET": offset,
                "QUANTIZED_VOLUME_SCALE": scale
            }

            batch_table_json = {
                "value": {
                    "byteOffset": 0,
                    "componentType": "FLOAT",
                    "type": "SCALAR"
                },
                "time": {
                    "byteOffset": length * 4,
                    "componentType": "FLOAT",
                    "type": "SCALAR"
                },
                "location": {
                    "byteOffset": length * 8,
                    "componentType": "SHORT",
                    "type": "VEC3"
                }
            }

            tile_length += header_length

            feature_table_json_min = json.dumps(feature_table_json, separators=(",", ":")) + "       "
            feature_table_trim = (tile_length + len(feature_table_json_min)) % 8
            if feature_table_trim != 0:
                feature_table_json_min = feature_table_json_min[:-feature_table_trim]

            tile_length += len(feature_table_json_min)

            feature_table_binary_byte_length = length * 4 + length * 3 * 2
            tile_length += feature_table_binary_byte_length
            feature_table_padding = tile_length % 8
            if feature_table_padding != 0:
                feature_table_padding = 8 - feature_table_padding
            tile_length += feature_table_padding

            batch_table_json_min = json.dumps(batch_table_json, separators=(",", ":")) + "       "
            batch_table_trim = (tile_length + len(batch_table_json_min)) % 8
            if batch_table_trim != 0:
                batch_table_json_min = batch_table_json_min[:-batch_table_trim]

            tile_length += len(batch_table_json_min)

            batch_table_binary_byte_length = length * 4 * 2 + length * 2 * 3
            tile_length += batch_table_binary_byte_length
            batch_table_padding = tile_length % 8
            if batch_table_padding != 0:
                batch_table_padding = 8 - batch_table_padding
            tile_length += batch_table_padding

            with open('{}/{}'.format(self.key, filename), mode='wb+') as outfile:
                outfile.write(np.string_(magic).tobytes())
                outfile.write(np.uint32(version).tobytes())
                outfile.write(np.uint32(tile_length).tobytes())
                outfile.write(np.uint32(len(feature_table_json_min)).tobytes())
                outfile.write(np.uint32(feature_table_binary_byte_length + feature_table_padding).tobytes())
                outfile.write(np.uint32(len(batch_table_json_min)).tobytes())
                outfile.write(np.uint32(batch_table_binary_byte_length + batch_table_padding).tobytes())
                outfile.write(np.string_(feature_table_json_min).tobytes())
                outfile.write(np.arange(length, dtype=np.uint32).tobytes())
                outfile.write(cartesian[::step, :].tobytes())
                for _ in range(feature_table_padding):
                    outfile.write(np.string_(" ").tobytes())
                outfile.write(np.string_(batch_table_json_min).tobytes())
                outfile.write(value[::step].astype(np.float32).tobytes())
                outfile.write(time[::step].astype(np.float32).tobytes())
                outfile.write(cartographic[::step, :].tobytes())
                for _ in range(batch_table_padding):
                    outfile.write(np.string_(" ").tobytes())
                outfile.seek(0)


    def cartographic_to_cartesian(self, start, end):
        lon = self.lon[start:end]
        lat = self.lat[start:end]
        alt = self.alt[start:end]
        size = lon.size

        cartographic = np.zeros(shape=(size, 3), dtype=np.int16)
        cartographic[:, 0] = (lon * 32767 / 180).astype(np.int16)
        cartographic[:, 1] = (lat * 32767 / 180).astype(np.int16)
        cartographic[:, 2] = (alt / 10).astype(np.int16)

        lon = lon * to_rad
        lat = lat * to_rad

        radiiSquared = np.array([40680631590769, 40680631590769, 40408299984661.445], dtype=np.float64)

        N1 = np.multiply(np.cos(lat), np.cos(lon))
        N2 = np.multiply(np.cos(lat), np.sin(lon))
        N3 = np.sin(lat)

        magnitude = np.sqrt(np.square(N1) + np.square(N2) + np.square(N3))

        N1 = N1 / magnitude
        N2 = N2 / magnitude
        N3 = N3 / magnitude

        K1 = radiiSquared[0] * N1
        K2 = radiiSquared[1] * N2
        K3 = radiiSquared[2] * N3

        gamma = np.sqrt(np.multiply(N1, K1) + np.multiply(N2, K2) + np.multiply(N3, K3))

        K1 = K1 / gamma
        K2 = K2 / gamma
        K3 = K3 / gamma

        N1 = np.multiply(N1, alt)
        N2 = np.multiply(N2, alt)
        N3 = np.multiply(N3, alt)

        # x = np.multiply((N1 + K1), np.random.normal(1, .00005, N1.size))
        # y = np.multiply((N2 + K2), np.random.normal(1, .00005, N1.size))
        # z = np.multiply((N3 + K3), np.random.normal(1, .00005, N1.size))

        x = N1 + K1
        y = N2 + K2
        z = N3 + K3

        offset = [float(np.min(x)), float(np.min(y)), float(np.min(z))]

        x = x - offset[0]
        y = y - offset[1]
        z = z - offset[2]

        scale = [float(abs(np.max(x))), float(abs(np.max(y))), float(abs(np.max(z)))]

        cartesian = np.zeros(shape=(size, 3), dtype=np.uint16)
        cartesian[:, 0] = (x / scale[0] * 65535.0).astype(np.uint16)
        cartesian[:, 1] = (y / scale[1] * 65535.0).astype(np.uint16)
        cartesian[:, 2] = (z / scale[2] * 65535.0).astype(np.uint16)

        region = [
            float(np.min(lon)),
            float(np.min(lat)),
            float(np.max(lon)),
            float(np.max(lat)),
            float(np.min(alt)),
            float(np.max(alt))
        ]

        return cartesian, offset, scale, cartographic, region

# %%
import sys
import os
import zarr
import numpy as np
import json
import datetime as dt

to_rad = np.pi / 180.0
to_deg = 180.0 / np.pi

def generate_point_cloud(variable, epoch, end, zarr_location, point_cloud_folder):
    """Generates json pointcloud from a given zarr file input

    Args:
        variable (_type_): _description_
        epoch (_type_): _description_
        end (_type_): _description_
        zarr_location (string): source zarr file.
        point_cloud_folder (string): destination folder for 3d tile json file.
    """

    #out_key = f"{os.getenv('CRS_OUTPUT_FLIGHT_PATH')}/{shortname}"
    #pc_out_key = f"{output_path}/point_cloud"

    '''
    try:
        os.mkdir(out_key)
    except:
        pass
    '''

    try:
        os.mkdir(point_cloud_folder)
    except:
        pass

    # LOAD THE DATA.
    store = zarr.DirectoryStore(zarr_location)
    root = zarr.group(store=store)

    chunk_id = root["chunk_id"][:]
    num_chunks = chunk_id.shape[0]
    id = np.argmax(chunk_id[:, 1] > epoch) - 1
    start_id = chunk_id[0 if id < 0 else id, 0]
    id = num_chunks - np.argmax(chunk_id[::-1, 1] < end)
    end_id = chunk_id[id, 0] if id < num_chunks else root["time"].size - 1

    root_epoch = root.attrs["epoch"]
    location = root["location"][start_id:end_id]
    lon = location[:, 0]
    lat = location[:, 1]
    alt = location[:, 2]
    value = root["value"][variable][start_id:end_id]
    time = root["time"][start_id:end_id]

    # filter data using mask
    epoch = epoch - root_epoch # date-time
    end = end - root_epoch
    mask = np.logical_and(time >= epoch, time <= end)
    lon = lon[mask]
    lat = lat[mask]
    alt = alt[mask]
    value = value[mask]
    time = time[mask]

    # Generate Pointcloud Tileset
    point_cloud = PointCloud(point_cloud_folder, lon, lat, alt, value, time, root_epoch)

    for tile in range(int(np.ceil(time.size / 530000))):
        start_id = tile * 530000
        end_id = np.min([start_id + 530000, time.size])
        point_cloud.schedule_task(tile, start_id, end_id)

    point_cloud.start()
    point_cloud.join()

tileset_json = {
	"asset": {
		"version": "1.0",
		"type": "Airborne Radar"
	},
	"root": {
		"geometricError": 1000000,
		"refine" : "REPLACE",
		"boundingVolume": {
            "region": []
        },
        "children": []
	},
    "properties": {
        "epoch": "",
        "refined": []
    }
}

#if __name__ == '__main__':
#    main(sys.argv[1], sys.argv[2], int(sys.argv[3]), int(sys.argv[4]))

# %%
# META needed for ingest
campaign = 'Hs3'
collection = "AirborneRadar"
dataset = "gpmValidationOlympexHiwrap"
variables = ["ref"]
renderers = ["point_cloud"]
chunk = 262144
to_rad = np.pi / 180
to_deg = 180 / np.pi

# %% [markdown]
# NOTE: for hiwrap data the direct s3access as file object didnot work. Maybe due to large size
# need to point to the local data file for the ingest to work.

# %%
# fileObj = "../../../../tmp/HS3_HIWRAP_20130925_kainnerchirp_175905-183056_v03.nc"
fileObj = "/tmp/Hs3/hiwrap/zarr/20130925/nc/HS3_HIWRAP_20130925_kuouterchirp_175902-183052_v03.nc"

# open dataset.
with xr.open_dataset(fileObj, decode_cf=False) as ds:
   
    # data columns extract
    ref = ds[variables[0]].values #Hiwrap radar reflectivity
    lat = ds['lat'].values
    lon = ds['lon'].values
    alt = ds['alt'].values # altitude of aircraft in meters
    roll = ds["roll"].values
    pitch = ds["pitch"].values
    head = ds["head"].values
    rad_range = ds["range"].values
num_col = ref.shape[0] # number of cols
num_row = ref.shape[1] # number of rows
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/itsc-fcx-n/lib/python3.10/site-packages/xarray/backends/file_manager.py:201, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     200 try:
# --> 201     file = self._cache[self._key]
#     202 except KeyError:
#
# File ~/miniconda3/envs/itsc-fcx-n/lib/python3.10/site-packages/xarray/backends/lru_cache.py:55, in LRUCache.__getitem__(self, key)
#      54 with self._lock:
# ---> 55     value = self._cache[key]
#      56     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('/tmp/Hs3/hiwrap/zarr/20130925/nc/HS3_HIWRAP_20130925_kuouterchirp_175902-183052_v03.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False))]
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# /home/sanjog/devs/FCX/FCX-Backend/src/campaigns/hs3/HIWRAP/hiwrap.ipynb Cell 9 in 5
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sanjog/devs/FCX/FCX-Backend/src/campaigns/hs3/HIWRAP/hiwrap.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> fileObj = "/tmp/Hs3/hiwrap/zarr/20130925/nc/HS3_HIWRAP_20130925_kuouterchirp_175902-183052_v03.nc"
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sanjog/devs/FCX/FCX-Backend/src/campaigns/hs3/HIWRAP/hiwrap.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> # open dataset.
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sanjog/devs/FCX/FCX-Backend/src/campaigns/hs3/HIWRAP/hiwrap.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> with xr.open_dataset(fileObj, decode_cf=False) as ds:
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sanjog/devs/FCX/FCX-Backend/src/campaigns/hs3/HIWRAP/hiwrap.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a>
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sanjog/devs/FCX/FCX-Backend/src/campaigns/hs3/HIWRAP/hiwrap.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     # data columns extract
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sanjog/devs/FCX/FCX-Backend/src/campaigns/hs3/HIWRAP/hiwrap.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     ref = ds[variables[0]].values #Hiwrap radar reflectivity
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/sanjog/devs/FCX/FCX-Backend/src/campaigns/hs3/HIWRAP/hiwrap.ipynb#X15sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     lat = ds['lat'].values
#
# File ~/miniconda3/envs/itsc-fcx-n/lib/python3.10/site-packages/xarray/backends/api.py:531, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, backend_kwargs, **kwargs)
#     519 decoders = _resolve_decoders_kwargs(
#     520     decode_cf,
#     521     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     527     decode_coords=decode_coords,
#     528 )
#     530 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 531 backend_ds = backend.open_dataset(
#     532     filename_or_obj,
#     533     drop_variables=drop_variables,
#     534     **decoders,
#     535     **kwargs,
#     536 )
#     537 ds = _dataset_from_backend_dataset(
#     538     backend_ds,
#     539     filename_or_obj,
#    (...)
#     547     **kwargs,
#     548 )
#     549 return ds
#
# File ~/miniconda3/envs/itsc-fcx-n/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:555, in NetCDF4BackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, format, clobber, diskless, persist, lock, autoclose)
#     534 def open_dataset(
#     535     self,
#     536     filename_or_obj,
#    (...)
#     551     autoclose=False,
#     552 ):
#     554     filename_or_obj = _normalize_path(filename_or_obj)
# --> 555     store = NetCDF4DataStore.open(
#     556         filename_or_obj,
#     557         mode=mode,
#     558         format=format,
#     559         group=group,
#     560         clobber=clobber,
#     561         diskless=diskless,
#     562         persist=persist,
#     563         lock=lock,
#     564         autoclose=autoclose,
#     565     )
#     567     store_entrypoint = StoreBackendEntrypoint()
#     568     with close_on_error(store):
#
# File ~/miniconda3/envs/itsc-fcx-n/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:384, in NetCDF4DataStore.open(cls, filename, mode, format, group, clobber, diskless, persist, lock, lock_maker, autoclose)
#     378 kwargs = dict(
#     379     clobber=clobber, diskless=diskless, persist=persist, format=format
#     380 )
#     381 manager = CachingFileManager(
#     382     netCDF4.Dataset, filename, mode=mode, kwargs=kwargs
#     383 )
# --> 384 return cls(manager, group=group, mode=mode, lock=lock, autoclose=autoclose)
#
# File ~/miniconda3/envs/itsc-fcx-n/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:332, in NetCDF4DataStore.__init__(self, manager, group, mode, lock, autoclose)
#     330 self._group = group
#     331 self._mode = mode
# --> 332 self.format = self.ds.data_model
#     333 self._filename = self.ds.filepath()
#     334 self.is_remote = is_remote_uri(self._filename)
#
# File ~/miniconda3/envs/itsc-fcx-n/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:393, in NetCDF4DataStore.ds(self)
#     391 @property
#     392 def ds(self):
# --> 393     return self._acquire()
#
# File ~/miniconda3/envs/itsc-fcx-n/lib/python3.10/site-packages/xarray/backends/netCDF4_.py:387, in NetCDF4DataStore._acquire(self, needs_lock)
#     386 def _acquire(self, needs_lock=True):
# --> 387     with self._manager.acquire_context(needs_lock) as root:
#     388         ds = _nc4_require_group(root, self._group, self._mode)
#     389     return ds
#
# File ~/miniconda3/envs/itsc-fcx-n/lib/python3.10/contextlib.py:135, in _GeneratorContextManager.__enter__(self)
#     133 del self.args, self.kwds, self.func
#     134 try:
# --> 135     return next(self.gen)
#     136 except StopIteration:
#     137     raise RuntimeError("generator didn't yield") from None
#
# File ~/miniconda3/envs/itsc-fcx-n/lib/python3.10/site-packages/xarray/backends/file_manager.py:189, in CachingFileManager.acquire_context(self, needs_lock)
#     186 @contextlib.contextmanager
#     187 def acquire_context(self, needs_lock=True):
#     188     """Context manager for acquiring a file."""
# --> 189     file, cached = self._acquire_with_cache_info(needs_lock)
#     190     try:
#     191         yield file
#
# File ~/miniconda3/envs/itsc-fcx-n/lib/python3.10/site-packages/xarray/backends/file_manager.py:207, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     205     kwargs = kwargs.copy()
#     206     kwargs["mode"] = self._mode
# --> 207 file = self._opener(*self._args, **kwargs)
#     208 if self._mode == "w":
#     209     # ensure file doesn't get overridden when opened again
#     210     self._mode = "a"
#
# File src/netCDF4/_netCDF4.pyx:2463, in netCDF4._netCDF4.Dataset.__init__()
#
# File src/netCDF4/_netCDF4.pyx:2026, in netCDF4._netCDF4._ensure_nc_success()
#
# OSError: [Errno -101] NetCDF: HDF error: b'/tmp/Hs3/hiwrap/zarr/20130925/nc/HS3_HIWRAP_20130925_kuouterchirp_175902-183052_v03.nc'

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:       (time: 115064, range: 353)
# Coordinates:
#   * range         (range) float32 74.95 149.9 224.8 ... 2.638e+04 2.646e+04
#   * time          (time) float32 3.239e+05 3.239e+05 ... 3.259e+05 3.259e+05
# Data variables: (12/34)
#     alt           (time) float32 1.673e+04 1.673e+04 ... 1.68e+04 1.68e+04
#     dopcorr       (time, range) float32 ...
#     doph          (time, range) float32 ...
#     dophu         (time, range) float32 ...
#     dopl          (time, range) float32 ...
#     doplh         (time, range) float32 ...
#     ...            ...
#     vacft         (time) float32 ...
#     vuh           float32 ...
#     vul           float32 ...
#     vulh          float32 ...
#     wvel          (time) float32 ...
#     year          int16 ...
# Attributes:
#     title:        HIWRAP Data, NASA Goddard Space Flight Center
#     filename:     /karldata4/tian/HS3/netcdf/2013/dist/dat/v3/hs3_hiwrap_kain...
#     experiment:   NASA HS3
#     source:       created from HIWRAP binary file, Version 0.0
#     comments:     Contact: lin.tian-1@nasa.gov
#     Conventions:  CF-1.6
#     history:      Wed Sep 23 15:20:50 2015: ncks -4 -L 4 -O /ghrc/ops/output/...
#     NCO:          4.3.7

# %%
seconds_array = ds['time'].values
seconds_array
# date = "20130925"
# base_date = np.datetime64('{}-{}-{}'.format(date[:4], date[4:6], date[6:]))

# # Convert seconds to timedelta
timedelta_array = seconds_array.astype('timedelta64[s]')

# # Add timedelta to base date to get datetime array
datetime_array = np.array([base_date + delta for delta in timedelta_array])
datetime_array
# Out:
# array(['2013-09-28T17:59:05', '2013-09-28T17:59:05',
#        '2013-09-28T17:59:05', ..., '2013-09-28T18:31:39',
#        '2013-09-28T18:31:39', '2013-09-28T18:31:39'],
#       dtype='datetime64[s]')

# %%
def ingest(folder, file, s3bucket):
    """
    Converts Level 1B hiwrap data from s3 to zarr file and then stores it in the provided folder
    Args:
        folder (string): name to hold the raw files.
        file (string): the s3 url to the raw file.
    """
    store = zarr.DirectoryStore(folder)
    root = zarr.group(store=store)
    
    # Create empty rows for modified data    
    z_chunk_id = root.create_dataset('chunk_id', shape=(0, 2), chunks=None, dtype=np.int64)
    z_location = root.create_dataset('location', shape=(0, 3), chunks=(chunk, None), dtype=np.float32)
    z_time = root.create_dataset('time', shape=(0), chunks=(chunk), dtype=np.int32)
    z_vars = root.create_group('value')
    z_ref = z_vars.create_dataset('ref', shape=(0), chunks=(chunk), dtype=np.float32)
    n_time = np.array([], dtype=np.int64)

    date = file.split("_")[2]
    base_time = np.datetime64('{}-{}-{}'.format(date[:4], date[4:6], date[6:]))

    print("Accessing file from S3 ", file)

    # read from s3 url (file) in s3 bucket.
    # fileObj = CRSaccess(file, s3bucket=s3bucket)
    fileObj = "../../../tmp/HS3_HIWRAP_20130925_kainnerchirp_175905-183056_v03.nc"

    # open dataset.
    with xr.open_dataset(fileObj, decode_cf=False) as ds:
        # added for time correction for over 24h UTC
        hr = add24hr(ds['time'].values)
        delta = (hr * 3600).astype('timedelta64[s]') + base_time
        # time correction end
        
        # data columns extract
        ref = ds[variables[0]].values #Hiwrap radar reflectivity
        lat = ds['lat'].values
        lon = ds['lon'].values
        alt = ds['alt'].values # altitude of aircraft in meters
        roll = ds["roll"].values
        pitch = ds["pitch"].values
        head = ds["head"].values
        rad_range = ds["range"].values
    num_col = ref.shape[0] # number of cols
    num_row = ref.shape[1] # number of rows

    # data frame formation
    delta = np.repeat(delta, num_row)
    lon = np.repeat(lon, num_row)
    lat = np.repeat(lat, num_row)
    alt = np.repeat(alt, num_row)
    roll = np.repeat(roll * to_rad, num_row)
    pitch = np.repeat(pitch * to_rad, num_row)
    head = np.repeat(head * to_rad, num_row)
    rad_range = np.tile(rad_range, num_col)
    ref = ref.flatten()

    # time correction.
    time = (delta - np.datetime64('1970-01-01')).astype('timedelta64[s]').astype(np.int64)

    x, y, z = down_vector(roll, pitch, head)
    x = np.multiply(x, np.divide(rad_range, 111000 * np.cos(lat * to_rad)))
    y = np.multiply(y, np.divide(rad_range, 111000))
    z = np.multiply(z, rad_range)

    lon = np.add(-x, lon)
    lat = np.add(-y, lat)
    alt = np.add(z, alt)

    # sort data by time
    sort_idx = np.argsort(time)

    lon = lon[sort_idx]
    lat = lat[sort_idx]
    alt = alt[sort_idx]
    ref = ref[sort_idx]
    time = time[sort_idx]

    # remove nan and infinite using mask ???
    mask = np.logical_and(np.isfinite(ref), alt > 0)
    lon = lon[mask]
    lat = lat[mask]
    alt = alt[mask]
    ref = ref[mask]
    time = time[mask]

    # Now populate (append) the empty rows with modified data.
    z_location.append(np.stack([lon, lat, alt], axis=-1))
    z_ref.append(ref)
    n_time = np.append(n_time, time)

    idx = np.arange(0, n_time.size, chunk)
    chunks = np.zeros(shape=(idx.size, 2), dtype=np.int64)
    chunks[:, 0] = idx
    chunks[:, 1] = n_time[idx]
    z_chunk_id.append(chunks)

    epoch = np.min(n_time)
    n_time = (n_time - epoch).astype(np.int32)
    z_time.append(n_time)

    # save it.
    root.attrs.put({
        "campaign": campaign,
        "collection": collection,
        "dataset": dataset,
        "variables": variables,
        "renderers": renderers,
        "epoch": int(epoch)
    })

# %% [markdown]
# Trigger point

# %%
def data_pre_process(bucket_name, field_campaign, input_data_dir, output_data_dir, instrument_name):
    s3_resource = boto3.resource('s3')
    s3bucket = s3_resource.Bucket(bucket_name)    
    keys = []
    for obj in s3bucket.objects.filter(
            Prefix=f"{field_campaign}/{input_data_dir}/{instrument_name}/HS3_HIWRAP_"):
        keys.append(obj.key)

    result = keys
    for s3_raw_file_key in result:
        # SOURCE DIR.
        sdate = s3_raw_file_key.split('_')[2]
        print(s3_raw_file_key)        
        print(sdate)        
        # return
        
        print(f'processing CRS file {s3_raw_file_key}')

        # CREATE A LOCAL DIR TO HOLD RAW DATA AND CONVERTED DATA
        folder = f"/tmp/hiwrap_hs3/zarr/{sdate}"
        point_cloud_folder = f"{folder}/point_cloud"
        if os.path.exists(folder): shutil.rmtree(f"{folder}")
        # os.mkdir(folder)
        Path(folder).mkdir(parents=True, exist_ok=True)
        # LOAD FROM SOURCE WITH NECESSARY PRE PROCESSING. CONVERT LEVEL 1B RAW FILES INTO ZARR FILE.
        ingest(folder, s3_raw_file_key, bucket_name)
        # CONVERT ZARR FILE INTO 3D TILESET JSON.
        generate_point_cloud("ref",  0,  1000000000000, folder, point_cloud_folder)

        # UPLOAD CONVERTED FILES.
        files = os.listdir(point_cloud_folder)
        s3 = boto3.client('s3')
        for file in files:
            fname = os.path.join(point_cloud_folder, file) # SOURCE
            s3name = f"{field_campaign}/{output_data_dir}/hiwrap/{sdate}/{file}" # DESTINATION
            print(f"uploaded to {s3name}.")
            upload_to_s3(fname, bucket_name, s3_name=s3name)


def hiwrap():
    # bucket_name = os.getenv('RAW_DATA_BUCKET')
    bucket_name="ghrc-fcx-field-campaigns-szg"
    field_campaign = "Hs3"
    input_data_dir = "instrument-raw-data"
    output_data_dir = "instrument-processed-data"
    instrument_name = "hiwrap"
    data_pre_process(bucket_name, field_campaign, input_data_dir, output_data_dir, instrument_name)


hiwrap()
# Out:
# Hs3/instrument-raw-data/hiwrap/HS3_HIWRAP_20130925_kainnerchirp_175905-183056_v03.nc
# 20130925
# processing CRS file Hs3/instrument-raw-data/hiwrap/HS3_HIWRAP_20130925_kainnerchirp_175905-183056_v03.nc
# Accessing file from S3  Hs3/instrument-raw-data/hiwrap/HS3_HIWRAP_20130925_kainnerchirp_175905-183056_v03.nc
# 49 25970000 26055482
# 49 25970000 26055482
# 48 25440000 25970000
# 48 25440000 25970000
# 47 24910000 25440000
# 47 24910000 25440000
# 46 24380000 24910000
# 46 24380000 24910000
# 45 23850000 24380000
# 45 23850000 24380000
# 44 23320000 23850000
# 44 23320000 23850000
# 43 22790000 23320000
# 43 22790000 23320000
# 42 22260000 22790000
# 42 22260000 22790000
# 41 21730000 22260000
# 41 21730000 22260000
# 40 21200000 21730000
# 40 21200000 21730000
# 39 20670000 21200000
# 39 20670000 21200000
# 38 20140000 20670000
# 38 20140000 20670000
# 37 19610000 20140000
# 37 19610000 20140000
# 36 19080000 19610000
# 36 19080000 19610000
# 35 18550000 19080000
# 35 18550000 19080000
# 34 18020000 18550000
# 34 18020000 18550000
# 33 17490000 18020000
# 33 17490000 18020000
# 32 16960000 17490000
# 32 16960000 17490000
# 31 16430000 16960000
# 31 16430000 16960000
# 30 15900000 16430000
# 30 15900000 16430000
# 29 15370000 15900000
# 29 15370000 15900000
# 28 14840000 15370000
# 28 14840000 15370000
# 27 14310000 14840000
# 27 14310000 14840000
# 26 13780000 14310000
# 26 13780000 14310000
# 25 13250000 13780000
# 25 13250000 13780000
# 24 12720000 13250000
# 24 12720000 13250000
# 23 12190000 12720000
# 23 12190000 12720000
# 22 11660000 12190000
# 22 11660000 12190000
# 21 11130000 11660000
# 21 11130000 11660000
# 20 10600000 11130000
# 20 10600000 11130000
# 19 10070000 10600000
# 19 10070000 10600000
# 18 9540000 10070000
# 18 9540000 10070000
# 17 9010000 9540000
# 17 9010000 9540000
# 16 8480000 9010000
# 16 8480000 9010000
# 15 7950000 8480000
# 15 7950000 8480000
# 14 7420000 7950000
# 14 7420000 7950000
# 13 6890000 7420000
# 13 6890000 7420000
# 12 6360000 6890000
# 12 6360000 6890000
# 11 5830000 6360000
# 11 5830000 6360000
# 10 5300000 5830000
# 10 5300000 5830000
# 9 4770000 5300000
# 9 4770000 5300000
# 8 4240000 4770000
# 8 4240000 4770000
# 7 3710000 4240000
# 7 3710000 4240000
# 6 3180000 3710000
# 6 3180000 3710000
# 5 2650000 3180000
# 5 2650000 3180000
# 4 2120000 2650000
# 4 2120000 2650000
# 3 1590000 2120000
# 3 1590000 2120000
# 2 1060000 1590000
# 2 1060000 1590000
# 1 530000 1060000
# 1 530000 1060000
# 0 0 530000
# 0 0 530000
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/47_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/35_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/43_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/44_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/18_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/39_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/18_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/5_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/34_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/47_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/2_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/24_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/13_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/38_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/18_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/37_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/24_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/24_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/41_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/47_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/32_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/31_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/3_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/25_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/47_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/36_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/42_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/23_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/11_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/49_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/9_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/10_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/14_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/7_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/26_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/22_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/17_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/37_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/8_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/13_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/40_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/5_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/38_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/33_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/48_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/20_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/14_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/8_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/29_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/21_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/8_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/26_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/9_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/44_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/10_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/43_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/0_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/3_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/0_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/33_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/35_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/13_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/38_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/32_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/0_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/26_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/23_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/2_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/12_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/15_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/16_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/8_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/24_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/35_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/49_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/45_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/12_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/15_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/23_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/18_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/18_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/34_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/32_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/4_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/26_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/31_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/21_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/43_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/29_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/39_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/32_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/25_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/6_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/23_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/2_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/48_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/13_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/13_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/21_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/14_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/25_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/16_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/7_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/tileset.json.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/6_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/21_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/23_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/9_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/11_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/38_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/12_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/33_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/1_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/7_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/28_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/34_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/22_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/32_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/9_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/12_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/30_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/16_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/38_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/48_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/11_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/15_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/23_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/30_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/48_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/7_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/28_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/49_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/44_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/40_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/36_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/37_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/27_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/37_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/46_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/4_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/5_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/19_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/19_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/32_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/22_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/17_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/46_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/15_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/5_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/22_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/34_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/29_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/14_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/15_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/28_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/6_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/6_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/42_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/27_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/45_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/11_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/2_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/8_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/14_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/30_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/5_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/43_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/36_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/16_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/44_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/48_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/10_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/31_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/46_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/19_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/40_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/46_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/7_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/49_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/16_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/33_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/1_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/26_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/38_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/27_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/8_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/27_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/21_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/36_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/10_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/1_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/41_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/15_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/28_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/22_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/20_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/45_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/0_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/22_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/41_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/30_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/42_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/14_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/25_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/25_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/20_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/34_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/26_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/31_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/20_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/9_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/40_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/36_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/6_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/2_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/13_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/42_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/4_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/49_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/19_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/33_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/4_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/1_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/42_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/44_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/40_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/20_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/35_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/36_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/3_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/5_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/34_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/17_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/4_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/4_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/46_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/2_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/41_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/1_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/37_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/21_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/9_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/31_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/3_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/29_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/43_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/42_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/30_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/29_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/0_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/7_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/41_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/39_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/25_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/39_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/3_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/10_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/45_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/24_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/47_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/35_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/12_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/40_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/45_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/28_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/41_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/49_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/6_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/29_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/17_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/19_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/37_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/48_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/17_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/16_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/44_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/10_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/43_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/45_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/46_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/24_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/12_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/0_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/35_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/1_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/30_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/3_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/20_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/11_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/18_1.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/27_32.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/31_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/17_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/11_4.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/39_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/47_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/33_8.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/28_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/27_2.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/19_16.pnts.
# uploaded to Hs3/instrument-processed-data/hiwrap/20130925/39_1.pnts.
